# %% [markdown]
# # Python Hands-on Practice Workbook
#
# ## Strings, Lists, Tuples and Dictionaries

# %% [markdown]
# ## Strings
# ### Major String Methods
# - upper(), lower(), title()
# - replace()
# - split()
# - strip()
# - find()
# - count()
# - startswith(), endswith()
# - len()

# %%
text="Data Modelling with Python"
print(text.upper())
print(text.lower())
print(text.replace("Python","AI"))
print(text.split())
print(len(text))
# Out:
# DATA MODELLING WITH PYTHON
# data modelling with python
# Data Modelling with AI
# ['Data', 'Modelling', 'with', 'Python']
# 26

# %% [markdown]
# ### Practice Question 1

# %%
# Write your code here
text = "I want to learn Python and have deep understanding of it. "
print(text.upper())
print(text.lower())
print(text.replace("Python", "AI"))
text = text.replace("Python", "AI")
print(text.split())
print(len(text))
print(text*100)
# Out:
# I WANT TO LEARN PYTHON AND HAVE DEEP UNDERSTANDING OF IT.
# i want to learn python and have deep understanding of it.
# I want to learn AI and have deep understanding of it.
# ['I', 'want', 'to', 'learn', 'AI', 'and', 'have', 'deep', 'understanding', 'of', 'it.']
# 54
# ...

# %% [markdown]
# ### Practice Question 2

# %%
# Write your code here
print((text*2 + "\n")*10)
# Out:
# I want to learn AI and have deep understanding of it. I want to learn AI and have deep understanding of it.
# I want to learn AI and have deep understanding of it. I want to learn AI and have deep understanding of it.
# I want to learn AI and have deep understanding of it. I want to learn AI and have deep understanding of it.
# I want to learn AI and have deep understanding of it. I want to learn AI and have deep understanding of it.
# I want to learn AI and have deep understanding of it. I want to learn AI and have deep understanding of it.
# I want to learn AI and have deep understanding of it. I want to learn AI and have deep understanding of it.
# I want to learn AI and have deep understanding of it. I want to learn AI and have deep understanding of it.
# I want to learn AI and have deep understanding of it. I want to learn AI and have deep understanding of it.
# I want to learn AI and have deep understanding of it. I want to learn AI and have deep understanding of it.
# ...

# %% [markdown]
# ## Lists
# ### Major List Methods
# - append()
# - extend()
# - insert()
# - remove()
# - pop()
# - sort()
# - reverse()
# - len(), max(), min(), sum()

# %%
courses=["Python","SQL","Power BI"]
courses.append("ML")
courses.insert(1,"Excel")
print(courses)
print(len(courses))
# Out:
# ['Python', 'Excel', 'SQL', 'Power BI', 'ML']
# 5

# %% [markdown]
# ### Practice Question 1

# %%
# Write your code here
mylearnings = ["Python", "Machine Learning", "Deep learning"]
mylearnings.append("AI")
mylearnings.insert(0,"SQL")
print(mylearnings)
# Out:
# ['SQL', 'Python', 'Machine Learning', 'Deep learning', 'AI']

# %% [markdown]
# ### Practice Question 2

# %%
# Write your code here
mylearnings.insert(0,"PowerBi")
mylearnings.insert(0,"Excel")
print(mylearnings)
# Out:
# ['Excel', 'PowerBi', 'SQL', 'Python', 'Machine Learning', 'Deep learning', 'AI']

# %% [markdown]
# ## Tuples
# ### Major Tuple Functions
# - len()
# - count()
# - index()
# - max()
# - min()

# %%
skills=("Python","SQL","Statistics","Python")
print(len(skills))
print(skills.count("Python"))
print(skills.index("SQL"))
# Out:
# 4
# 2
# 1

# %% [markdown]
# ### Practice Question 1

# %%
# Write your code here

# %% [markdown]
# ### Practice Question 2

# %%
# Write your code here

# %% [markdown]
# ## Dictionaries
# ### Major Dictionary Methods
# - keys()
# - values()
# - items()
# - get()
# - update()
# - pop()
# - clear()
# - len()

# %%
employee={"Name":"Suyashi","Role":"Manager","Location":"Gurgaon"}
print(employee.keys())
print(employee.get("Role"))
employee.update({"Department":"Training"})
print(employee)
# Out:
# dict_keys(['Name', 'Role', 'Location'])
# Manager
# {'Name': 'Suyashi', 'Role': 'Manager', 'Location': 'Gurgaon', 'Department': 'Training'}

# %% [markdown]
# ### Practice Question 1

# %%
# Write your code here

# %% [markdown]
# ### Practice Question 2

# %%
# Write your code here

# %% [markdown]
# ## Practice Questions
#
# ### Strings
# 1. Create a string with your name and print it in uppercase.
# 2. Count characters in "Artificial Intelligence".
#
# ### Lists
# 1. Create a list of 5 numbers and print maximum value.
# 2. Add "Excel" to ["Python","SQL"].
#
# ### Tuples
# 1. Create tuple of 4 cities and print second city.
# 2. Count elements in (10,20,30,40,50).
#
# ### Dictionaries
# 1. Create student dictionary and print Score.
# 2. Add Department key and display dictionary.

# %% [markdown]
# ## Mini Challenge
# Create a dictionary containing Name, Skills(List), Location and print all values.

# %%
# Solution here

resume = {"Name":"Ayushi Gupta", "Skills":["Excel","VBA", "SQL", "PowerBi"], "Location":["Delhi","Gurugram"]}
print(resume)
# Out:
# {'Name': 'Ayushi Gupta', 'Skills': ['Excel', 'VBA', 'SQL', 'PowerBi'], 'Location': ['Delhi', 'Gurugram']}
